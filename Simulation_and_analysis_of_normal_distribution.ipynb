# %% [markdown]
# <a href="https://colab.research.google.com/github/majisandhyatara-creator/STAT_Project1/blob/main/Simulation_and_analysis_of_normal_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


mean = 0
std_dev = 1
n = 10000


data = np.random.normal(mean, std_dev, n)


sample_mean = np.mean(data)
sample_variance = np.var(data)

print("Theoretical Mean:", mean)
print("Sample Mean:", sample_mean)
print("Theoretical Variance:", std_dev**2)
print("Sample Variance:", sample_variance)


plt.figure(figsize=(8,5))
count, bins, ignored = plt.hist(data, bins=50, density=True)


x = np.linspace(min(bins), max(bins), 1000)
pdf = norm.pdf(x, mean, std_dev)

plt.plot(x, pdf)

plt.title("Normal Distribution Simulation")
plt.xlabel("Value")
plt.ylabel("Density")


plt.savefig("output.png")

plt.show()
# Out:
# Theoretical Mean: 0
# Sample Mean: 0.009998465231118001
# Theoretical Variance: 1
# Sample Variance: 1.0006558475634668
